# %%
#Import dependencies
import pandas as pd
import gmaps
import requests
from citipy import citipy
import random
import numpy as np
#Import API key
from cnfg import gkey

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
from cnfg import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key

# %%
import time
from datetime import datetime

# %%
#create empty list for weather data
city_data = []
#Beggining of loging
print("Beggining of data retrieval      ")
print("---------------------------------")

#create counters.
record_count = 1
set_count = 1
# Out:
# Beggining of data retrieval
# ---------------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_sensation = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_sensation})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | nijar
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 1 | henties bay
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | adrar
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | kruisfontein
# Processing Record 11 of Set 1 | vila franca do campo
# Processing Record 12 of Set 1 | krasnaya gorka
# Processing Record 13 of Set 1 | waiuku
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | rowlett
# Processing Record 16 of Set 1 | tuatapere
# Processing Record 17 of Set 1 | lata
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 1 | robe
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | whitehorse
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | asau
# Processing Record 30 of Set 1 | parrita
# Processing Record 31 of Set 1 | smolenka
# Processing Record 32 of Set 1 | baruun-urt
# Processing Record 33 of Set 1 | beloha
# Processing Record 34 of Set 1 | jaguaruna
# Processing Record 35 of Set 1 | kharitonovo
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | banyo
# Processing Record 39 of Set 1 | koundara
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | srednekolymsk
# Processing Record 43 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 1 | yar-sale
# Processing Record 45 of Set 1 | miandrivazo
# Processing Record 46 of Set 1 | churapcha
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | kavieng
# Processing Record 50 of Set 1 | cabo san lucas
# Processing Record 1 of Set 2 | jalaun
# Processing Record 2 of Set 2 | kahului
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | longonjo
# Processing Record 5 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 6 of Set 2 | tokonou
# Processing Record 7 of Set 2 | vardo
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | safranbolu
# Processing Record 10 of Set 2 | kaitangata
# Processing Record 11 of Set 2 | bilma
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | great falls
# Processing Record 14 of Set 2 | cabedelo
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | hambantota
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | kenitra
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | yabelo
# Processing Record 22 of Set 2 | hasaki
# Processing Record 23 of Set 2 | riohacha
# Processing Record 24 of Set 2 | lazaro cardenas
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | ellsworth
# Processing Record 27 of Set 2 | sakakah
# Processing Record 28 of Set 2 | broome
# Processing Record 29 of Set 2 | salalah
# Processing Record 30 of Set 2 | college
# Processing Record 31 of Set 2 | pochutla
# Processing Record 32 of Set 2 | saint-augustin
# Processing Record 33 of Set 2 | ust-kuyga
# Processing Record 34 of Set 2 | daurala
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | la ronge
# Processing Record 37 of Set 2 | nouakchott
# Processing Record 38 of Set 2 | aparecida do taboado
# Processing Record 39 of Set 2 | yumen
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | bengkulu
# Processing Record 42 of Set 2 | norman wells
# Processing Record 43 of Set 2 | fairbanks
# Processing Record 44 of Set 2 | coihaique
# Processing Record 45 of Set 2 | katherine
# Processing Record 46 of Set 2 | bata
# Processing Record 47 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 2 | punta arenas
# Processing Record 1 of Set 3 | airai
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | dali
# Processing Record 4 of Set 3 | cidreira
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | iqaluit
# Processing Record 7 of Set 3 | atkinson
# Processing Record 8 of Set 3 | puunsi
# City not found. Skipping...
# Processing Record 9 of Set 3 | aklavik
# Processing Record 10 of Set 3 | asadabad
# Processing Record 11 of Set 3 | ribeira grande
# Processing Record 12 of Set 3 | kieta
# Processing Record 13 of Set 3 | ongandjera
# Processing Record 14 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 3 | mahebourg
# Processing Record 16 of Set 3 | huarmey
# Processing Record 17 of Set 3 | ixtapa
# Processing Record 18 of Set 3 | vao
# Processing Record 19 of Set 3 | barcelos
# Processing Record 20 of Set 3 | virden
# Processing Record 21 of Set 3 | burica
# City not found. Skipping...
# Processing Record 22 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 23 of Set 3 | vanavara
# Processing Record 24 of Set 3 | chumikan
# Processing Record 25 of Set 3 | the valley
# Processing Record 26 of Set 3 | mar del plata
# Processing Record 27 of Set 3 | pevek
# Processing Record 28 of Set 3 | westport
# Processing Record 29 of Set 3 | hamilton
# Processing Record 30 of Set 3 | sao joao da barra
# Processing Record 31 of Set 3 | east london
# Processing Record 32 of Set 3 | baykit
# Processing Record 33 of Set 3 | moron
# Processing Record 34 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 3 | launceston
# Processing Record 36 of Set 3 | ilulissat
# Processing Record 37 of Set 3 | bredasdorp
# Processing Record 38 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 3 | hami
# Processing Record 40 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 3 | segou
# Processing Record 42 of Set 3 | ukiah
# Processing Record 43 of Set 3 | lompoc
# Processing Record 44 of Set 3 | san patricio
# Processing Record 45 of Set 3 | puerto ayacucho
# Processing Record 46 of Set 3 | morehead
# Processing Record 47 of Set 3 | griffith
# Processing Record 48 of Set 3 | wanning
# Processing Record 49 of Set 3 | klaksvik
# Processing Record 50 of Set 3 | erenhot
# Processing Record 1 of Set 4 | kashi
# Processing Record 2 of Set 4 | negele
# City not found. Skipping...
# Processing Record 3 of Set 4 | zhigansk
# Processing Record 4 of Set 4 | aitape
# Processing Record 5 of Set 4 | carauari
# Processing Record 6 of Set 4 | lixourion
# Processing Record 7 of Set 4 | mount isa
# Processing Record 8 of Set 4 | tambacounda
# Processing Record 9 of Set 4 | bluff
# Processing Record 10 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 11 of Set 4 | lavrentiya
# Processing Record 12 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 4 | dahod
# Processing Record 14 of Set 4 | waingapu
# Processing Record 15 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 4 | wasilla
# Processing Record 17 of Set 4 | san pedro
# Processing Record 18 of Set 4 | cherskiy
# Processing Record 19 of Set 4 | nanning
# Processing Record 20 of Set 4 | fortuna
# Processing Record 21 of Set 4 | batagay-alyta
# Processing Record 22 of Set 4 | katsiveli
# City not found. Skipping...
# Processing Record 23 of Set 4 | guerrero negro
# Processing Record 24 of Set 4 | luanda
# Processing Record 25 of Set 4 | mitsamiouli
# Processing Record 26 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 4 | owensboro
# Processing Record 28 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 4 | butaritari
# Processing Record 30 of Set 4 | lunino
# Processing Record 31 of Set 4 | labuan
# Processing Record 32 of Set 4 | zabolottya
# City not found. Skipping...
# Processing Record 33 of Set 4 | chateauroux
# Processing Record 34 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 4 | baoqing
# Processing Record 36 of Set 4 | azangaro
# Processing Record 37 of Set 4 | orel
# Processing Record 38 of Set 4 | sernovodsk
# Processing Record 39 of Set 4 | pechora
# Processing Record 40 of Set 4 | coquimbo
# Processing Record 41 of Set 4 | sept-iles
# Processing Record 42 of Set 4 | carnarvon
# Processing Record 43 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 4 | neuquen
# Processing Record 45 of Set 4 | sumbawanga
# Processing Record 46 of Set 4 | pangnirtung
# Processing Record 47 of Set 4 | puerto escondido
# Processing Record 48 of Set 4 | jamestown
# Processing Record 49 of Set 4 | ahipara
# Processing Record 50 of Set 4 | saint-philippe
# Processing Record 1 of Set 5 | dolny kubin
# Processing Record 2 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 5 | ponta do sol
# Processing Record 4 of Set 5 | codrington
# Processing Record 5 of Set 5 | constitucion
# Processing Record 6 of Set 5 | ferme-neuve
# Processing Record 7 of Set 5 | sitka
# Processing Record 8 of Set 5 | itarema
# Processing Record 9 of Set 5 | fatima
# Processing Record 10 of Set 5 | belaya gora
# Processing Record 11 of Set 5 | altamira
# Processing Record 12 of Set 5 | humaita
# Processing Record 13 of Set 5 | fort nelson
# Processing Record 14 of Set 5 | shakiso
# Processing Record 15 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 5 | oshkosh
# Processing Record 17 of Set 5 | chokurdakh
# Processing Record 18 of Set 5 | lingyuan
# Processing Record 19 of Set 5 | nioro
# Processing Record 20 of Set 5 | harbour breton
# Processing Record 21 of Set 5 | turgenevo
# Processing Record 22 of Set 5 | tim
# Processing Record 23 of Set 5 | cape town
# Processing Record 24 of Set 5 | mantena
# Processing Record 25 of Set 5 | khandyga
# Processing Record 26 of Set 5 | sakaiminato
# Processing Record 27 of Set 5 | robertsport
# Processing Record 28 of Set 5 | lufilufi
# Processing Record 29 of Set 5 | ipixuna
# Processing Record 30 of Set 5 | tecoanapa
# Processing Record 31 of Set 5 | port hardy
# Processing Record 32 of Set 5 | half moon bay
# Processing Record 33 of Set 5 | tahe
# Processing Record 34 of Set 5 | kirkenes
# Processing Record 35 of Set 5 | abbeville
# Processing Record 36 of Set 5 | barra velha
# Processing Record 37 of Set 5 | tangshan
# Processing Record 38 of Set 5 | oussouye
# Processing Record 39 of Set 5 | yarmouth
# Processing Record 40 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 41 of Set 5 | parkes
# Processing Record 42 of Set 5 | madras
# Processing Record 43 of Set 5 | chernyshevskiy
# Processing Record 44 of Set 5 | naze
# Processing Record 45 of Set 5 | rosarito
# Processing Record 46 of Set 5 | san quintin
# Processing Record 47 of Set 5 | simao
# Processing Record 48 of Set 5 | san cristobal
# Processing Record 49 of Set 5 | bathsheba
# Processing Record 50 of Set 5 | dunedin
# Processing Record 1 of Set 6 | christchurch
# Processing Record 2 of Set 6 | sterling
# Processing Record 3 of Set 6 | nerchinskiy zavod
# Processing Record 4 of Set 6 | sembe
# Processing Record 5 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 6 | esperance
# Processing Record 7 of Set 6 | paamiut
# Processing Record 8 of Set 6 | lodja
# Processing Record 9 of Set 6 | hithadhoo
# Processing Record 10 of Set 6 | beaupre
# Processing Record 11 of Set 6 | kalianget
# Processing Record 12 of Set 6 | yangambi
# Processing Record 13 of Set 6 | saskylakh
# Processing Record 14 of Set 6 | leningradskiy
# Processing Record 15 of Set 6 | minot
# Processing Record 16 of Set 6 | bambous virieux
# Processing Record 17 of Set 6 | palauig
# Processing Record 18 of Set 6 | hamada
# Processing Record 19 of Set 6 | boa vista
# Processing Record 20 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 21 of Set 6 | mansa
# Processing Record 22 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 6 | rome
# Processing Record 24 of Set 6 | kiunga
# Processing Record 25 of Set 6 | dikson
# Processing Record 26 of Set 6 | seoul
# Processing Record 27 of Set 6 | ballina
# Processing Record 28 of Set 6 | moerai
# Processing Record 29 of Set 6 | krasnoselkup
# Processing Record 30 of Set 6 | bakel
# Processing Record 31 of Set 6 | boljarovo
# City not found. Skipping...
# Processing Record 32 of Set 6 | lorengau
# Processing Record 33 of Set 6 | ucluelet
# Processing Record 34 of Set 6 | lahat
# Processing Record 35 of Set 6 | preobrazheniye
# Processing Record 36 of Set 6 | havre-saint-pierre
# Processing Record 37 of Set 6 | olinda
# Processing Record 38 of Set 6 | tocopilla
# Processing Record 39 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 40 of Set 6 | hobyo
# Processing Record 41 of Set 6 | taiyuan
# Processing Record 42 of Set 6 | norfolk
# Processing Record 43 of Set 6 | liusha
# Processing Record 44 of Set 6 | ust-omchug
# Processing Record 45 of Set 6 | nacala
# Processing Record 46 of Set 6 | ishigaki
# Processing Record 47 of Set 6 | te anau
# Processing Record 48 of Set 6 | murgab
# Processing Record 49 of Set 6 | port blair
# Processing Record 50 of Set 6 | bud
# Processing Record 1 of Set 7 | namibe
# Processing Record 2 of Set 7 | tancitaro
# Processing Record 3 of Set 7 | matara
# Processing Record 4 of Set 7 | carutapera
# Processing Record 5 of Set 7 | omsukchan
# Processing Record 6 of Set 7 | rawah
# Processing Record 7 of Set 7 | dongying
# Processing Record 8 of Set 7 | floro
# Processing Record 9 of Set 7 | myingyan
# Processing Record 10 of Set 7 | robstown
# Processing Record 11 of Set 7 | khatanga
# Processing Record 12 of Set 7 | belyy yar
# Processing Record 13 of Set 7 | mount gambier
# Processing Record 14 of Set 7 | yenagoa
# Processing Record 15 of Set 7 | andenes
# Processing Record 16 of Set 7 | hohoe
# Processing Record 17 of Set 7 | ostersund
# Processing Record 18 of Set 7 | faanui
# Processing Record 19 of Set 7 | thoen
# Processing Record 20 of Set 7 | hovd
# Processing Record 21 of Set 7 | port augusta
# Processing Record 22 of Set 7 | peruibe
# Processing Record 23 of Set 7 | souillac
# Processing Record 24 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 7 | fort myers beach
# Processing Record 26 of Set 7 | matiri
# Processing Record 27 of Set 7 | xuddur
# Processing Record 28 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 7 | margate
# Processing Record 30 of Set 7 | beyneu
# Processing Record 31 of Set 7 | soe
# Processing Record 32 of Set 7 | port said
# Processing Record 33 of Set 7 | abrau-dyurso
# Processing Record 34 of Set 7 | geraldton
# Processing Record 35 of Set 7 | salmas
# Processing Record 36 of Set 7 | ahuimanu
# Processing Record 37 of Set 7 | mugumu
# Processing Record 38 of Set 7 | beringovskiy
# Processing Record 39 of Set 7 | tabarqah
# City not found. Skipping...
# Processing Record 40 of Set 7 | craigieburn
# Processing Record 41 of Set 7 | puro
# Processing Record 42 of Set 7 | gat
# Processing Record 43 of Set 7 | cuamba
# Processing Record 44 of Set 7 | aksu
# Processing Record 45 of Set 7 | dickinson
# Processing Record 46 of Set 7 | yellowknife
# Processing Record 47 of Set 7 | sarangani
# Processing Record 48 of Set 7 | palmerston
# Processing Record 49 of Set 7 | buraydah
# Processing Record 50 of Set 7 | tome-acu
# City not found. Skipping...
# Processing Record 1 of Set 8 | barreirinhas
# Processing Record 2 of Set 8 | yanam
# Processing Record 3 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 4 of Set 8 | zhezkazgan
# Processing Record 5 of Set 8 | buriti bravo
# Processing Record 6 of Set 8 | gillette
# Processing Record 7 of Set 8 | portland
# Processing Record 8 of Set 8 | mbeya
# Processing Record 9 of Set 8 | saint-paul
# Processing Record 10 of Set 8 | alofi
# Processing Record 11 of Set 8 | rawson
# Processing Record 12 of Set 8 | hopkinton
# Processing Record 13 of Set 8 | mnogovershinnyy
# Processing Record 14 of Set 8 | jobat
# Processing Record 15 of Set 8 | iranshahr
# Processing Record 16 of Set 8 | maarianhamina
# Processing Record 17 of Set 8 | claveria
# Processing Record 18 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 8 | sangar
# Processing Record 20 of Set 8 | nurota
# Processing Record 21 of Set 8 | port hedland
# Processing Record 22 of Set 8 | pedasi
# Processing Record 23 of Set 8 | makakilo city
# Processing Record 24 of Set 8 | kupino
# Processing Record 25 of Set 8 | kochi
# Processing Record 26 of Set 8 | lagoa
# Processing Record 27 of Set 8 | jambusar
# Processing Record 28 of Set 8 | bria
# Processing Record 29 of Set 8 | natal
# Processing Record 30 of Set 8 | ranong
# Processing Record 31 of Set 8 | ajdabiya
# Processing Record 32 of Set 8 | kaeo
# Processing Record 33 of Set 8 | bubaque
# Processing Record 34 of Set 8 | kimbe
# Processing Record 35 of Set 8 | fulitun
# City not found. Skipping...
# Processing Record 36 of Set 8 | coahuayana
# Processing Record 37 of Set 8 | kindia
# Processing Record 38 of Set 8 | broken hill
# Processing Record 39 of Set 8 | lasa
# Processing Record 40 of Set 8 | mehamn
# Processing Record 41 of Set 8 | birobidzhan
# Processing Record 42 of Set 8 | yimnon
# Processing Record 43 of Set 8 | gamba
# Processing Record 44 of Set 8 | tiznit
# Processing Record 45 of Set 8 | totma
# Processing Record 46 of Set 8 | dubbo
# Processing Record 47 of Set 8 | avera
# Processing Record 48 of Set 8 | gigmoto
# Processing Record 49 of Set 8 | mayor pablo lagerenza
# Processing Record 50 of Set 8 | tadepallegudem
# Processing Record 1 of Set 9 | khash
# Processing Record 2 of Set 9 | koungou
# Processing Record 3 of Set 9 | partyzany
# Processing Record 4 of Set 9 | honningsvag
# Processing Record 5 of Set 9 | rincon
# Processing Record 6 of Set 9 | vredendal
# Processing Record 7 of Set 9 | carahue
# Processing Record 8 of Set 9 | buluang
# Processing Record 9 of Set 9 | yerbogachen
# Processing Record 10 of Set 9 | ararat
# Processing Record 11 of Set 9 | cartagena
# Processing Record 12 of Set 9 | vila
# Processing Record 13 of Set 9 | kloulklubed
# Processing Record 14 of Set 9 | fatehpur
# Processing Record 15 of Set 9 | tabou
# Processing Record 16 of Set 9 | teguldet
# Processing Record 17 of Set 9 | maniitsoq
# Processing Record 18 of Set 9 | grindavik
# Processing Record 19 of Set 9 | beatrice
# Processing Record 20 of Set 9 | ulaanbaatar
# Processing Record 21 of Set 9 | tanete
# Processing Record 22 of Set 9 | san policarpo
# Processing Record 23 of Set 9 | kiama
# Processing Record 24 of Set 9 | harper
# Processing Record 25 of Set 9 | chantada
# Processing Record 26 of Set 9 | beaverlodge
# Processing Record 27 of Set 9 | longyearbyen
# Processing Record 28 of Set 9 | agirish
# Processing Record 29 of Set 9 | jumla
# Processing Record 30 of Set 9 | eureka
# Processing Record 31 of Set 9 | northam
# Processing Record 32 of Set 9 | nieuw amsterdam
# Processing Record 33 of Set 9 | makokou
# Processing Record 34 of Set 9 | kamaishi
# Processing Record 35 of Set 9 | lalomanu
# City not found. Skipping...
# Processing Record 36 of Set 9 | inhambane
# Processing Record 37 of Set 9 | la rioja
# Processing Record 38 of Set 9 | morondava
# Processing Record 39 of Set 9 | uyuni
# Processing Record 40 of Set 9 | yatou
# Processing Record 41 of Set 9 | comodoro rivadavia
# Processing Record 42 of Set 9 | awbari
# Processing Record 43 of Set 9 | clyde river
# Processing Record 44 of Set 9 | kununurra
# Processing Record 45 of Set 9 | natitingou
# Processing Record 46 of Set 9 | ikwiriri
# Processing Record 47 of Set 9 | varna
# Processing Record 48 of Set 9 | duki
# Processing Record 49 of Set 9 | bad wurzach
# Processing Record 50 of Set 9 | shimoda
# Processing Record 1 of Set 10 | kurilsk
# Processing Record 2 of Set 10 | marfino
# Processing Record 3 of Set 10 | petrivka
# Processing Record 4 of Set 10 | aksarka
# Processing Record 5 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 10 | ancud
# Processing Record 7 of Set 10 | lebu
# Processing Record 8 of Set 10 | garchitorena
# Processing Record 9 of Set 10 | santa rosa
# Processing Record 10 of Set 10 | saint george
# Processing Record 11 of Set 10 | parana
# Processing Record 12 of Set 10 | weyburn
# Processing Record 13 of Set 10 | pangai
# Processing Record 14 of Set 10 | zima
# Processing Record 15 of Set 10 | tabukiniberu
# City not found. Skipping...
# Processing Record 16 of Set 10 | taburao
# City not found. Skipping...
# Processing Record 17 of Set 10 | vostok
# Processing Record 18 of Set 10 | tromso
# Processing Record 19 of Set 10 | laguna
# Processing Record 20 of Set 10 | japura
# Processing Record 21 of Set 10 | acapulco
# Processing Record 22 of Set 10 | wewak
# Processing Record 23 of Set 10 | sola
# Processing Record 24 of Set 10 | amapa
# Processing Record 25 of Set 10 | tessaoua
# Processing Record 26 of Set 10 | durban
# Processing Record 27 of Set 10 | quelimane
# Processing Record 28 of Set 10 | pasni
# Processing Record 29 of Set 10 | bacsalmas
# Processing Record 30 of Set 10 | luderitz
# Processing Record 31 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 10 | vidalia
# Processing Record 33 of Set 10 | dehloran
# Processing Record 34 of Set 10 | nan
# Processing Record 35 of Set 10 | topeka
# Processing Record 36 of Set 10 | kuching
# Processing Record 37 of Set 10 | iracoubo
# Processing Record 38 of Set 10 | severobaykalsk
# Processing Record 39 of Set 10 | bonthe
# Processing Record 40 of Set 10 | totness
# Processing Record 41 of Set 10 | vila velha
# Processing Record 42 of Set 10 | torbay
# Processing Record 43 of Set 10 | haapiti
# Processing Record 44 of Set 10 | luwuk
# Processing Record 45 of Set 10 | manjakandriana
# Processing Record 46 of Set 10 | sapao
# City not found. Skipping...
# Processing Record 47 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 48 of Set 10 | novyy nekouz
# Processing Record 49 of Set 10 | porirua
# Processing Record 50 of Set 10 | jinka
# Processing Record 1 of Set 11 | hailar
# Processing Record 2 of Set 11 | morro bay
# Processing Record 3 of Set 11 | aqtobe
# Processing Record 4 of Set 11 | urengoy
# Processing Record 5 of Set 11 | xapuri
# Processing Record 6 of Set 11 | turukhansk
# Processing Record 7 of Set 11 | vestmanna
# Processing Record 8 of Set 11 | havelock
# Processing Record 9 of Set 11 | san andres
# Processing Record 10 of Set 11 | grand gaube
# Processing Record 11 of Set 11 | labuhan
# Processing Record 12 of Set 11 | letterkenny
# Processing Record 13 of Set 11 | hauterive
# Processing Record 14 of Set 11 | campbell river
# Processing Record 15 of Set 11 | dinajpur
# Processing Record 16 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 11 | kichera
# Processing Record 18 of Set 11 | kapit
# Processing Record 19 of Set 11 | mareeba
# Processing Record 20 of Set 11 | yulara
# Processing Record 21 of Set 11 | biak
# Processing Record 22 of Set 11 | lethem
# Processing Record 23 of Set 11 | poum
# Processing Record 24 of Set 11 | murray bridge
# Processing Record 25 of Set 11 | orangeburg
# Processing Record 26 of Set 11 | safaga
# Processing Record 27 of Set 11 | maningrida
# Processing Record 28 of Set 11 | san juan
# Processing Record 29 of Set 11 | rayachoti
# Processing Record 30 of Set 11 | bandarbeyla
# Processing Record 31 of Set 11 | narsaq
# Processing Record 32 of Set 11 | carbonia
# Processing Record 33 of Set 11 | umm lajj
# Processing Record 34 of Set 11 | lovington
# Processing Record 35 of Set 11 | coronado
# Processing Record 36 of Set 11 | opuwo
# Processing Record 37 of Set 11 | rio grande
# Processing Record 38 of Set 11 | tres palos
# Processing Record 39 of Set 11 | kirkuk
# Processing Record 40 of Set 11 | nanortalik
# Processing Record 41 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 11 | vanimo
# Processing Record 43 of Set 11 | ternate
# Processing Record 44 of Set 11 | novikovo
# Processing Record 45 of Set 11 | marawi
# Processing Record 46 of Set 11 | normal
# Processing Record 47 of Set 11 | la fleche
# Processing Record 48 of Set 11 | berlevag
# Processing Record 49 of Set 11 | namatanai
# Processing Record 50 of Set 11 | bell ville
# Processing Record 1 of Set 12 | sydney
# Processing Record 2 of Set 12 | xining
# Processing Record 3 of Set 12 | atherton
# Processing Record 4 of Set 12 | maubeuge
# Processing Record 5 of Set 12 | qaqortoq
# Processing Record 6 of Set 12 | meulaboh
# Processing Record 7 of Set 12 | ketchikan
# Processing Record 8 of Set 12 | saint-pierre
# Processing Record 9 of Set 12 | deputatskiy
# Processing Record 10 of Set 12 | mandalgovi
# Processing Record 11 of Set 12 | pisco
# Processing Record 12 of Set 12 | caravelas
# Processing Record 13 of Set 12 | kualakapuas
# Processing Record 14 of Set 12 | bafra
# Processing Record 15 of Set 12 | strezhevoy
# Processing Record 16 of Set 12 | aplahoue
# Processing Record 17 of Set 12 | severo-kurilsk
# Processing Record 18 of Set 12 | shirokiy
# Processing Record 19 of Set 12 | manzhouli
# Processing Record 20 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 12 | dharchula
# Processing Record 22 of Set 12 | ginir
# Processing Record 23 of Set 12 | dambulla
# Processing Record 24 of Set 12 | hattiesburg
# Processing Record 25 of Set 12 | nelson bay
# Processing Record 26 of Set 12 | playa vicente
# Processing Record 27 of Set 12 | rio gallegos
# Processing Record 28 of Set 12 | sohag
# Processing Record 29 of Set 12 | liaozhong
# Processing Record 30 of Set 12 | sao filipe
# Processing Record 31 of Set 12 | jahrom
# City not found. Skipping...
# Processing Record 32 of Set 12 | taoudenni
# Processing Record 33 of Set 12 | palmer
# Processing Record 34 of Set 12 | kouango
# Processing Record 35 of Set 12 | deori khas
# Processing Record 36 of Set 12 | polunochnoye
# Processing Record 37 of Set 12 | sawtell
# Processing Record 38 of Set 12 | puerto el triunfo
# Processing Record 39 of Set 12 | liverpool
# Processing Record 40 of Set 12 | hay river
# Processing Record 41 of Set 12 | kilakarai
# Processing Record 42 of Set 12 | port lincoln
# Processing Record 43 of Set 12 | kondinskoye
# Processing Record 44 of Set 12 | praia da vitoria
# Processing Record 45 of Set 12 | saldanha
# Processing Record 46 of Set 12 | hargeysa
# Processing Record 47 of Set 12 | tupik
# Processing Record 48 of Set 12 | edson
# Processing Record 49 of Set 12 | mirnyy
# Processing Record 50 of Set 12 | mopti
# Processing Record 1 of Set 13 | koslan
# Processing Record 2 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 13 | aras
# Processing Record 4 of Set 13 | marsh harbour
# Processing Record 5 of Set 13 | popondetta
# Processing Record 6 of Set 13 | kushima
# Processing Record 7 of Set 13 | russell
# Processing Record 8 of Set 13 | taltal
# Processing Record 9 of Set 13 | nguru
# Processing Record 10 of Set 13 | florianopolis
# Processing Record 11 of Set 13 | cozumel
# Processing Record 12 of Set 13 | merritt island
# Processing Record 13 of Set 13 | tongren
# Processing Record 14 of Set 13 | tuma
# Processing Record 15 of Set 13 | santa maria
# Processing Record 16 of Set 13 | ugoofaaru
# Processing Record 17 of Set 13 | kawalu
# Processing Record 18 of Set 13 | progreso
# Processing Record 19 of Set 13 | sorland
# Processing Record 20 of Set 13 | thunder bay
# Processing Record 21 of Set 13 | laredo
# Processing Record 22 of Set 13 | pontal do parana
# Processing Record 23 of Set 13 | baherden
# Processing Record 24 of Set 13 | maizuru
# Processing Record 25 of Set 13 | ust-nera
# Processing Record 26 of Set 13 | kayerkan
# Processing Record 27 of Set 13 | hirara
# Processing Record 28 of Set 13 | benjamin constant
# Processing Record 29 of Set 13 | troyes
# Processing Record 30 of Set 13 | touros
# Processing Record 31 of Set 13 | arkadak
# Processing Record 32 of Set 13 | carnot
# Processing Record 33 of Set 13 | muros
# Processing Record 34 of Set 13 | marsabit
# Processing Record 35 of Set 13 | adre
# Processing Record 36 of Set 13 | pacific grove
# Processing Record 37 of Set 13 | slonim
# Processing Record 38 of Set 13 | evensk
# Processing Record 39 of Set 13 | kars
# Processing Record 40 of Set 13 | katsuura
# Processing Record 41 of Set 13 | prince rupert
# Processing Record 42 of Set 13 | pesqueira
# Processing Record 43 of Set 13 | haines junction
# Processing Record 44 of Set 13 | afyonkarahisar
# Processing Record 45 of Set 13 | bemidji
# Processing Record 46 of Set 13 | sharjah
# Processing Record 47 of Set 13 | mandurah
# Processing Record 48 of Set 13 | ewa beach
# Processing Record 49 of Set 13 | blaubeuren
# Processing Record 50 of Set 13 | athabasca
# Processing Record 1 of Set 14 | tiksi
# Processing Record 2 of Set 14 | manavalakurichi
# Processing Record 3 of Set 14 | turayf
# Processing Record 4 of Set 14 | kumluca
# Processing Record 5 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 6 of Set 14 | vuktyl
# Processing Record 7 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 14 | yeppoon
# Processing Record 9 of Set 14 | kidal
# Processing Record 10 of Set 14 | dingle
# Processing Record 11 of Set 14 | riyadh
# Processing Record 12 of Set 14 | cap malheureux
# Processing Record 13 of Set 14 | alzey
# Processing Record 14 of Set 14 | khani
# Processing Record 15 of Set 14 | turkistan
# Processing Record 16 of Set 14 | caxito
# Processing Record 17 of Set 14 | nara
# Processing Record 18 of Set 14 | katastarion
# Processing Record 19 of Set 14 | sabang
# Processing Record 20 of Set 14 | redwater
# Processing Record 21 of Set 14 | pasighat
# Processing Record 22 of Set 14 | kenora
# Processing Record 23 of Set 14 | gejiu
# Processing Record 24 of Set 14 | sinnamary
# Processing Record 25 of Set 14 | isangel
# Processing Record 26 of Set 14 | waipawa
# Processing Record 27 of Set 14 | puerto baquerizo moreno
# Processing Record 28 of Set 14 | chulakivka
# Processing Record 29 of Set 14 | jabinyanah
# Processing Record 30 of Set 14 | kyaukse
# Processing Record 31 of Set 14 | bom jesus
# Processing Record 32 of Set 14 | arlit
# Processing Record 33 of Set 14 | bauchi
# Processing Record 34 of Set 14 | chapais
# Processing Record 35 of Set 14 | karratha
# Processing Record 36 of Set 14 | inongo
# Processing Record 37 of Set 14 | severnyy
# Processing Record 38 of Set 14 | turka
# Processing Record 39 of Set 14 | piranhas
# Processing Record 40 of Set 14 | road town
# Processing Record 41 of Set 14 | tomatlan
# Processing Record 42 of Set 14 | wattegama
# Processing Record 43 of Set 14 | velizh
# Processing Record 44 of Set 14 | qeshm
# Processing Record 45 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 14 | brae
# Processing Record 47 of Set 14 | cabadiangan
# Processing Record 48 of Set 14 | richards bay
# Processing Record 49 of Set 14 | nicolas bravo
# Processing Record 50 of Set 14 | bilibino
# Processing Record 1 of Set 15 | siderno
# Processing Record 2 of Set 15 | valparaiso
# Processing Record 3 of Set 15 | leh
# Processing Record 4 of Set 15 | tessalit
# Processing Record 5 of Set 15 | izumo
# Processing Record 6 of Set 15 | chipinge
# Processing Record 7 of Set 15 | jinchang
# Processing Record 8 of Set 15 | dongzhen
# Processing Record 9 of Set 15 | bermeo
# Processing Record 10 of Set 15 | muana
# Processing Record 11 of Set 15 | bakchar
# Processing Record 12 of Set 15 | usevya
# Processing Record 13 of Set 15 | abnub
# Processing Record 14 of Set 15 | palembang
# Processing Record 15 of Set 15 | brigantine
# Processing Record 16 of Set 15 | mudgal
# Processing Record 17 of Set 15 | nhulunbuy
# Processing Record 18 of Set 15 | sciacca
# Processing Record 19 of Set 15 | ducheng
# Processing Record 20 of Set 15 | aswan
# Processing Record 21 of Set 15 | aporawan
# City not found. Skipping...
# Processing Record 22 of Set 15 | kibala
# Processing Record 23 of Set 15 | west bay
# Processing Record 24 of Set 15 | fort saint james
# Processing Record 25 of Set 15 | mahon
# Processing Record 26 of Set 15 | ngunguru
# Processing Record 27 of Set 15 | ambovombe
# Processing Record 28 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 29 of Set 15 | calgary
# Processing Record 30 of Set 15 | talnakh
# Processing Record 31 of Set 15 | winslow
# Processing Record 32 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 33 of Set 15 | villena
# Processing Record 34 of Set 15 | lethbridge
# Processing Record 35 of Set 15 | dabat
# Processing Record 36 of Set 15 | barabinsk
# Processing Record 37 of Set 15 | belmonte
# Processing Record 38 of Set 15 | esterhazy
# Processing Record 39 of Set 15 | mitzic
# Processing Record 40 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 15 | saint-joseph
# Processing Record 42 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 15 | roma
# Processing Record 44 of Set 15 | oskarshamn
# Processing Record 45 of Set 15 | byron bay
# Processing Record 46 of Set 15 | tilichiki
# Processing Record 47 of Set 15 | kachug
# Processing Record 48 of Set 15 | zhangye
# Processing Record 49 of Set 15 | san jeronimo
# Processing Record 50 of Set 15 | solnechnyy
# Processing Record 1 of Set 16 | noumea
# Processing Record 2 of Set 16 | energetik
# Processing Record 3 of Set 16 | marzuq
# Processing Record 4 of Set 16 | san rafael
# Processing Record 5 of Set 16 | wawa
# Processing Record 6 of Set 16 | sajanan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)

# %%
city_data_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hobart -42.8794  147.3294      6.14        90           0
# 1          Nijar  36.9665   -2.2060     26.80        54           0
# 2    Tuktoyaktuk  69.4541 -133.0374     12.00        82          75
# 3    Henties Bay -22.1160   14.2845     12.44        91           1
# 4     Georgetown   5.4112  100.3354     28.83        90          20
# ..           ...      ...       ...       ...       ...         ...
# 692    Energetik  51.7445   58.7934     21.46        59          84
# 693       Marzuq  14.4000   46.4667     25.94        69         100
# 694   San Rafael -34.6177  -68.3301     16.06        32           0
# 695         Wawa   9.9022    4.4192     21.97        97         100
# 696      Sajanan  37.0573    9.2426     24.51        74           0
#
#      Wind Speed Country                 Date   Current Description
# 0          0.00      AU  2022-08-11 20:59:14             clear sky
# 1          1.54      ES  2022-08-11 20:59:15             clear sky
# 2          7.72      CA  2022-08-11 20:59:15         broken clouds
# 3          4.39      NA  2022-08-11 20:59:16             clear sky
# 4          1.03      MY  2022-08-11 20:57:47            few clouds
# ..          ...     ...                  ...                   ...
# 692        3.14      RU  2022-08-11 21:18:37         broken clouds
# 693        2.37      YE  2022-08-11 21:18:37       overcast clouds
# 694        4.39      AR  2022-08-11 21:18:37             clear sky
# 695        3.21      NG  2022-08-11 21:18:38  heavy intensity rain
# 696        1.26      TN  2022-08-11 21:18:38             clear sky
#
# [697 rows x 10 columns]

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
